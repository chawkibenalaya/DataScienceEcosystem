# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:7d966e51-392e-4014-b8c0-e3fecea35e88.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:2d6b092b-6f56-4dd4-9914-75701e9d0d62.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Java

# %% [markdown]
# ![4-dslanguages.png](attachment:5633b7e8-31c3-44eb-b5a3-c676409e849d.png)

# %% [markdown]
# | Data Science Tools          |
# |-----------------------------|
# | Jupyter Notebook            |
# | RStudio                     |
# | Apache Zeppelin             |

# %% [markdown]
# ![6-dstools.png](attachment:b0e140a9-f3fe-4d65-b770-3e7b95b02c36.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![7-introarithmetic.png](attachment:fda03f62-86c8-409d-bba6-5e9f5ef121ff.png)

# %%
# his a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:f67f990e-ad2c-4407-82d3-4d0d1fb256d5.png)

# %%
#This will convert 200 minutes to hours by diving by 60
total_minutes = 200
hours = total_minutes // 60  
minutes = total_minutes % 60  
# Display result
f"{hours}h et {minutes} minutes"
# Out:
# '3h et 20 minutes'

# %% [markdown]
# ![9-hourstominutes.png](attachment:78eb1aec-07b9-4df7-8241-8e1beca7790d.png)

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Create a table of Data Science tools
# - Convert minutes to hours using Python
# - Understand Markdown syntax for formatting
# - Identify key takeaways from the course

# %% [markdown]
# ![10-objectives.png](attachment:3cd6d1e8-15fc-4944-adea-ef130b5e2744.png)

# %% [markdown]
# ## Author
#
# Chawki Ben Alaya

# %% [markdown]
# ![11-authordetails.png](attachment:f96b8ece-b274-42fd-b8e6-2a01ada7547f.png)
